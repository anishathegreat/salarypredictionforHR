# %% [markdown]
# <a href="https://colab.research.google.com/github/anishathegreat/salarypredictionforHR/blob/main/Salary_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# %%
#imported the dataset
file = pd.read_csv('/content/salarydata.csv')
file.head()
# Out:
#    age         workclass  education  education-num      marital-status  \
# 0   39         State-gov  Bachelors             13       Never-married
# 1   50  Self-emp-not-inc  Bachelors             13  Married-civ-spouse
# 2   38           Private    HS-grad              9            Divorced
# 3   53           Private       11th              7  Married-civ-spouse
# 4   28           Private  Bachelors             13  Married-civ-spouse
#
#           occupation   relationship   race     sex  capital-gain  \
# 0       Adm-clerical  Not-in-family  White    Male          2174
# 1    Exec-managerial        Husband  White    Male             0
# 2  Handlers-cleaners  Not-in-family  White    Male             0
# 3  Handlers-cleaners        Husband  Black    Male             0
# 4     Prof-specialty           Wife  Black  Female             0
#
#    capital-loss  hours-per-week native-country salary
# 0             0              40  United-States  <=50K
# 1             0              13  United-States  <=50K
# 2             0              40  United-States  <=50K
# 3             0              40  United-States  <=50K
# 4             0              40           Cuba  <=50K
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['education-num'].plot(kind='hist', bins=20, title='education-num')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['capital-gain'].plot(kind='hist', bins=20, title='capital-gain')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['hours-per-week'].plot(kind='hist', bins=20, title='hours-per-week')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('workclass').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_5.groupby('education').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_6.groupby('marital-status').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_7.groupby('occupation').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='age', y='education-num', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9.plot(kind='scatter', x='education-num', y='capital-gain', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10.plot(kind='scatter', x='capital-gain', y='hours-per-week', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['capital-loss']
#   ys = series['age']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('capital-loss', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('workclass')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='workclass', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('capital-loss')
# _ = plt.ylabel('age')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['capital-loss']
#   ys = series['age']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('capital-loss', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('education')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='education', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('capital-loss')
# _ = plt.ylabel('age')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['capital-loss']
#   ys = series['age']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_13.sort_values('capital-loss', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('marital-status')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='marital-status', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('capital-loss')
# _ = plt.ylabel('age')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['capital-loss']
#   ys = series['age']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_14.sort_values('capital-loss', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('occupation')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='occupation', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('capital-loss')
# _ = plt.ylabel('age')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_15['age'].plot(kind='line', figsize=(8, 4), title='age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['education-num'].plot(kind='line', figsize=(8, 4), title='education-num')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['capital-gain'].plot(kind='line', figsize=(8, 4), title='capital-gain')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18['hours-per-week'].plot(kind='line', figsize=(8, 4), title='hours-per-week')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['education'].value_counts()
#     for x_label, grp in _df_19.groupby('workclass')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('workclass')
# _ = plt.ylabel('education')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['marital-status'].value_counts()
#     for x_label, grp in _df_20.groupby('education')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('education')
# _ = plt.ylabel('marital-status')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['occupation'].value_counts()
#     for x_label, grp in _df_21.groupby('marital-status')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('marital-status')
# _ = plt.ylabel('occupation')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['relationship'].value_counts()
#     for x_label, grp in _df_22.groupby('occupation')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('occupation')
# _ = plt.ylabel('relationship')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_23['workclass'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_23, x='age', y='workclass', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_24['education'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_24, x='age', y='education', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_25['marital-status'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_25, x='age', y='marital-status', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_26['occupation'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_26, x='age', y='occupation', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
#checked if there is any null value in the dataset
file.isnull().sum()  #we can see that there is no null values in the data set
# Out:
# age               0
# workclass         0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %%
file['workclass'].unique()
#values in the attribute work-class
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', '?', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
#we can see that there is a '?' in the set of values
file.loc[file['workclass'] == '?', 'workclass'] = 'Unknown'
#changed '?' into 'Unknown'

# %%
file['occupation'].unique()
#values in the attribute occupation
# Out:
# array(['Adm-clerical', 'Exec-managerial', 'Handlers-cleaners',
#        'Prof-specialty', 'Other-service', 'Sales', 'Craft-repair',
#        'Transport-moving', 'Farming-fishing', 'Machine-op-inspct',
#        'Tech-support', '?', 'Protective-serv', 'Armed-Forces',
#        'Priv-house-serv'], dtype=object)

# %%
#we can see that there is a '?' in the set of values
file.loc[file['occupation'] == '?', 'occupation'] = 'Unknown'
#changed '?' into 'Unknown'

# %%
file['native-country'].unique()
#values in the attribute native-country
# Out:
# array(['United-States', 'Cuba', 'Jamaica', 'India', '?', 'Mexico',
#        'South', 'Puerto-Rico', 'Honduras', 'England', 'Canada', 'Germany',
#        'Iran', 'Philippines', 'Italy', 'Poland', 'Columbia', 'Cambodia',
#        'Thailand', 'Ecuador', 'Laos', 'Taiwan', 'Haiti', 'Portugal',
#        'Dominican-Republic', 'El-Salvador', 'France', 'Guatemala',
#        'China', 'Japan', 'Yugoslavia', 'Peru',
#        'Outlying-US(Guam-USVI-etc)', 'Scotland', 'Trinadad&Tobago',
#        'Greece', 'Nicaragua', 'Vietnam', 'Hong', 'Ireland', 'Hungary',
#        'Holand-Netherlands'], dtype=object)

# %%
#we can see that there is a '?' in the set of values
file.loc[file['native-country'] == '?', 'native-country'] = 'Unknown'
#changed '?' into 'Unknown'

# %%
file = file.drop(columns = ['capital-gain', 'capital-loss', 'education-num'])
#unnecessary since its something that happens after salary is given.
file
# Out:
#        age         workclass   education      marital-status  \
# 0       39         State-gov   Bachelors       Never-married
# 1       50  Self-emp-not-inc   Bachelors  Married-civ-spouse
# 2       38           Private     HS-grad            Divorced
# 3       53           Private        11th  Married-civ-spouse
# 4       28           Private   Bachelors  Married-civ-spouse
# ...    ...               ...         ...                 ...
# 32556   27           Private  Assoc-acdm  Married-civ-spouse
# 32557   40           Private     HS-grad  Married-civ-spouse
# 32558   58           Private     HS-grad             Widowed
# 32559   22           Private     HS-grad       Never-married
# 32560   52      Self-emp-inc     HS-grad  Married-civ-spouse
#
#               occupation   relationship   race     sex  hours-per-week  \
# 0           Adm-clerical  Not-in-family  White    Male              40
# 1        Exec-managerial        Husband  White    Male              13
# 2      Handlers-cleaners  Not-in-family  White    Male              40
# 3      Handlers-cleaners        Husband  Black    Male              40
# 4         Prof-specialty           Wife  Black  Female              40
# ...                  ...            ...    ...     ...             ...
# 32556       Tech-support           Wife  White  Female              38
# 32557  Machine-op-inspct        Husband  White    Male              40
# 32558       Adm-clerical      Unmarried  White  Female              40
# 32559       Adm-clerical      Own-child  White    Male              20
# 32560    Exec-managerial           Wife  White  Female              40
#
#       native-country salary
# 0      United-States  <=50K
# 1      United-States  <=50K
# 2      United-States  <=50K
# 3      United-States  <=50K
# 4               Cuba  <=50K
# ...              ...    ...
# 32556  United-States  <=50K
# 32557  United-States   >50K
# 32558  United-States  <=50K
# 32559  United-States  <=50K
# 32560  United-States   >50K
#
# [32561 rows x 11 columns]

# %%
plt.hist(file['age'])
plt.title('Age distribution')
plt.rcParams['figure.figsize'] = (9,4)
plt.xlabel('Age')
plt.ylabel('Count')
plt.xticks(np.arange(20,100,5))
plt.show()

# %%
file['workclass'].value_counts().plot(kind = 'pie')
plt.rcParams['figure.figsize'] = (7,10)
plt.title('Work Class')
plt.show()

# %%
file['education'].value_counts().plot(kind = 'bar')
plt.rcParams['figure.figsize'] = (9,5)
plt.xlabel('Education level')
plt.ylabel('People')
plt.title('Education')
plt.grid()
plt.show()

# %%
file['marital-status'].value_counts().plot(kind = 'pie')
plt.rcParams['figure.figsize'] = (7,10)
plt.title('Marital Status')
plt.show()

# %%
file['occupation'].value_counts().plot(kind = 'bar')
plt.rcParams['figure.figsize'] = (9,4)
plt.xlabel('occupations')
plt.ylabel('People')
plt.title('Occupations')
plt.grid()
plt.show()

# %%
file['relationship'].value_counts().plot(kind = 'bar')
plt.rcParams['figure.figsize'] = (5,4)
plt.xlabel('Relationship status')
plt.ylabel('People')
plt.title('Relationship Status')
plt.grid()
plt.show()

# %%
file['race'].value_counts().plot(kind = 'pie')
plt.rcParams['figure.figsize'] = (7,10)
plt.title('Race')
plt.show()

# %%
file['sex'].value_counts().plot(kind = 'pie')
plt.rcParams['figure.figsize'] = (7,10)
plt.title('Sex')
plt.show()

# %%
plt.boxplot(file['hours-per-week'])
plt.rcParams['figure.figsize'] = (4,5)
plt.show()

# %%
file['native-country'].value_counts().plot(kind = 'bar')
plt.rcParams['figure.figsize'] = (15,4)
plt.xlabel('country')
plt.ylabel('People')
plt.title('Native country')
plt.show()

# %% [markdown]
# **Pre-processing of dataset**

# %%
target = file.pop('salary')
#Extracted and defined the target

# %%
character_columns = file.dtypes.pipe(lambda x: x[x == 'object']).index
character_columns
#Extracting columns having character values
# Out:
# Index(['workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'race', 'sex', 'native-country'],
#       dtype='object')

# %%
label_mapping ={}
for col in character_columns:
  file[col], label_mapping[col] = pd.factorize(file[col])
#converting these character values to numeric values
file.head()
# Out:
#    age  workclass  education  marital-status  occupation  relationship  race  \
# 0   39          0          0               0           0             0     0
# 1   50          1          0               1           1             1     0
# 2   38          2          1               2           2             0     0
# 3   53          2          2               1           2             1     1
# 4   28          2          0               1           3             2     1
#
#    sex  hours-per-week  native-country
# 0    0              40               0
# 1    0              13               0
# 2    0              40               0
# 3    0              40               0
# 4    1              40               1

# %%
#Here in our target we have 2 classes <=50 and >50
#Hence we need to use a binary classifier
#So we will use logistic regression

#normalizing the data
scaler = StandardScaler()  #we scale the data for larger values not affecting the smaller values
file = scaler.fit_transform(file.values)

# %%
#split the data
x_train, x_test, y_train, y_test = train_test_split(file,target,test_size = 0.3, random_state = 42)
#Train the model
classifier = LogisticRegression().fit(x_train, y_train)
print("---- Training complete-----")
# Out:
# ---- Training complete-----

# %%
prediction = classifier.predict(x_test)
#generate report
print(classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.80      0.94      0.86      7455
#         >50K       0.55      0.24      0.33      2314
#
#     accuracy                           0.77      9769
#    macro avg       0.68      0.59      0.60      9769
# weighted avg       0.74      0.77      0.74      9769

# %% [markdown]
# **Hyper Parameter Tuning**

# %%
# example of grid searching key hyperparametres for logistic regression
from sklearn.datasets import make_blobs
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
# define dataset
X, y = make_blobs(n_samples=1000, centers=2, n_features=100, cluster_std=20)
# define models and parameters
model = LogisticRegression()
solvers = ['newton-cg', 'lbfgs', 'liblinear']
penalty = ['l2']
c_values = [100, 10, 1.0, 0.1, 0.01]
# define grid search
grid = dict(solver=solvers,penalty=penalty,C=c_values)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
grid_result = grid_search.fit(X, y)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.958667 using {'C': 0.01, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.952667 (0.018785) with: {'C': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.955667 (0.014067) with: {'C': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.951667 (0.018812) with: {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.953000 (0.018285) with: {'C': 10, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.957667 (0.015638) with: {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.952000 (0.018690) with: {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.952000 (0.018690) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.954667 (0.017461) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.952667 (0.018962) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.952667 (0.020155) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.952000 (0.019900) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.953000 (0.018646) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.958667 (0.019619) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.958667 (0.019619) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.956333 (0.018705) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
classifier = LogisticRegression(penalty = grid_result.best_params_['penalty'], C = grid_result.best_params_['C'], solver = grid_result.best_params_['solver']).fit(x_train, y_train)
prediction = classifier.predict(x_test)

print("---- Training complete-----")
# Out:
# ---- Training complete-----

# %%
#generate report
print(classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.80      0.94      0.86      7455
#         >50K       0.56      0.23      0.32      2314
#
#     accuracy                           0.77      9769
#    macro avg       0.68      0.59      0.59      9769
# weighted avg       0.74      0.77      0.74      9769

# %% [markdown]
# **Random Forest Model**

# %%
from sklearn.ensemble import RandomForestClassifier
#Train the model
model = RandomForestClassifier(n_estimators=20)
model.fit(x_train, y_train)
print("---- Training complete-----")
# Out:
# ---- Training complete-----

# %%
y_pred = model.predict(x_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.86      0.90      0.88      7455
#         >50K       0.63      0.54      0.58      2314
#
#     accuracy                           0.81      9769
#    macro avg       0.75      0.72      0.73      9769
# weighted avg       0.81      0.81      0.81      9769

# %% [markdown]
# **SVM Model**

# %%
from sklearn.svm import SVC
svc = SVC(kernel='linear')
svc.fit(x_train, y_train)
y_pred = svc.predict(x_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.76      1.00      0.87      7455
#         >50K       0.00      0.00      0.00      2314
#
#     accuracy                           0.76      9769
#    macro avg       0.38      0.50      0.43      9769
# weighted avg       0.58      0.76      0.66      9769
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']}

grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3)

# fitting the model for grid search
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.801 total time=  27.4s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.802 total time=  27.4s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.795 total time=  20.9s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.803 total time=  30.2s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.798 total time=  23.3s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.799 total time=  12.0s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.796 total time=  10.2s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.801 total time=  11.1s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.797 total time=  11.6s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.798 total time=  11.3s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.757 total time=  12.4s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.757 total time=  12.6s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.758 total time=  19.8s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.758 total time=  28.7s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.758 total time=  11.8s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.757 total time=  11.8s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.757 total time=  11.9s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.758 total time=  10.6s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.758 total time=  11.7s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.758 total time=  11.7s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.757 total time=  10.7s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.757 total time=  11.2s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.758 total time=   9.4s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.758 total time=  10.9s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.758 total time=  10.9s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.824 total time=  33.4s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.822 total time=  27.3s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.815 total time=  33.2s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.818 total time=  32.8s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.817 total time=  27.3s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.814 total time=  12.0s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.810 total time=  10.7s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.813 total time=  12.9s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.817 total time=  11.6s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.815 total time=  11.5s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.772 total time=  12.0s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.776 total time=  10.7s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.769 total time=  11.3s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.771 total time=  12.0s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.773 total time=  11.9s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.757 total time=  12.6s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.757 total time=  12.6s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.758 total time=  12.7s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.758 total time=  13.0s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.758 total time=  13.0s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.757 total time=  11.4s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.757 total time=  11.7s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.758 total time=  11.5s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.758 total time=  11.7s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.758 total time=  11.9s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.810 total time=  45.8s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.813 total time=  45.4s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.808 total time=  47.9s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.812 total time=  46.6s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.800 total time=  48.1s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.817 total time=  15.1s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.815 total time=  15.6s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.815 total time=  14.0s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.818 total time=  14.4s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.813 total time=  14.0s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.798 total time=  12.2s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.794 total time=  12.7s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.800 total time=  11.9s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.797 total time=  11.4s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.798 total time=  12.3s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.757 total time=  12.7s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.757 total time=  12.7s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.758 total time=  12.6s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.758 total time=  14.2s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.758 total time=  13.2s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.757 total time=  13.5s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.757 total time=  13.7s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.758 total time=  13.4s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.758 total time=  13.2s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.758 total time=  13.3s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.799 total time= 1.5min
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.795 total time= 1.4min
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.795 total time= 1.5min
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.799 total time= 1.4min
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.789 total time= 1.7min
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.816 total time=  32.9s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.810 total time=  34.1s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.809 total time=  33.4s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.811 total time=  34.7s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.807 total time=  34.4s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.813 total time=  16.5s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.801 total time=  16.1s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.811 total time=  18.6s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.810 total time=  16.1s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.813 total time=  17.7s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.771 total time=  13.2s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.777 total time=  12.5s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.770 total time=  13.2s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.769 total time=  13.4s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.773 total time=  13.5s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.757 total time=  14.8s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.757 total time=  14.3s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.758 total time=  14.7s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.758 total time=  14.8s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.758 total time=  14.7s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.791 total time= 7.6min
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.791 total time= 6.5min
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.785 total time= 6.2min
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.796 total time= 8.0min
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.783 total time= 5.9min
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.803 total time= 3.2min
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.803 total time= 2.7min
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.798 total time= 3.0min
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.805 total time= 3.0min
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.798 total time= 2.9min
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.818 total time=  44.9s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.808 total time=  44.7s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.814 total time=  47.9s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.819 total time=  46.9s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.816 total time=  46.2s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.798 total time=  18.1s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.794 total time=  17.8s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.797 total time=  20.3s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.793 total time=  17.5s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.797 total time=  18.2s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.757 total time=  16.2s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.757 total time=  15.6s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.758 total time=  15.1s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.758 total time=  15.2s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.758 total time=  15.0s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
# print best parameter after tuning
print(grid.best_params_)

# print how our model looks after hyper-parameter tuning
print(grid.best_estimator_)
# Out:
# {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
# SVC(C=1, gamma=1)

# %%
grid_predictions = grid.predict(x_test)
# print classification report
print(classification_report(y_test, grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.85      0.93      0.89      7455
#         >50K       0.67      0.49      0.57      2314
#
#     accuracy                           0.82      9769
#    macro avg       0.76      0.71      0.73      9769
# weighted avg       0.81      0.82      0.81      9769

# %% [markdown]
# **Testing on a Particular Case**

# %%
#generate a particular test data
test_data = []
test_data.append(int(input('Enter the age : ')))
test_data.append(input('Enter the work-class : '))
test_data.append(input('Enter the education level : '))
test_data.append(input('Enter the marital-status : '))
test_data.append(input('Enter the occupation : '))
test_data.append(input('Enter the relationship status : '))
test_data.append(input('Enter the race : '))
test_data.append(input('Enter the sex : '))
test_data.append(int(input('Enter the no. of hours he/she work per week : ')))
test_data.append(input('Enter the native-country : '))
# Out:
# Enter the age : 52
# Enter the work-class : Private
# Enter the education level : 9
# Enter the marital-status : Never married
# Enter the occupation : sales
# Enter the relationship status : not-in-family
# Enter the race : white
# Enter the sex : female
# Enter the no. of hours he/she work per week : 40
# Enter the native-country : cuba

# %%
#testing for this particular test data
df = pd.DataFrame({'age' : [test_data[0]],
                   'work-class' : [test_data[1]],
                   'education' : [test_data[2]],
                   'marital-status' : [test_data[3]],
                   'occupation' : [test_data[4]],
                   'relationship' : [test_data[5]],
                   'race' : [test_data[6]],
                   'sex' : [test_data[7]],
                   'hours-per-week' : [test_data[8]],
                   'native-country' : [test_data[9]]
                   })
character_data = df.dtypes.pipe(lambda x: x[x == 'object']).index
test_label_mapping ={}
for col in character_data:
  df[col], test_label_mapping[col] = pd.factorize(df[col])
test_scaler = StandardScaler()
df = test_scaler.fit_transform(df.values)
pred = grid.predict(df)
print(f"The salary will be {pred[0]}")
# Out:
# The salary will be <=50K
